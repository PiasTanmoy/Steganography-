# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers.core import Activation
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.utils import np_utils
np.random.seed(0)
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
from sklearn.utils import shuffle
import pandas as pd
from PIL import Image
import cv2
# Out:
# Using TensorFlow backend.

# %%
X_train = pd.read('drive/My Drive/Google_Colab/Steganography/dataset/Sample/cover1.jpg')

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-25744418-bcbf-499d-8025-d47420961893" name="files[]" multiple disabled />
#      <output id="result-25744418-bcbf-499d-8025-d47420961893">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving conceal.jpg to conceal.jpg

# %%
a = np.load('conceal.jpg')

# %%
image = cv2.imread("conceal.jpg")

# %%
import cv2
cover1 = cv2.imread("drive/My Drive/images steganography final/jpg_input/set-4/hide_12.jpg")
cover2 = cv2.imread("drive/My Drive/images steganography final/output/Image Steganography/Hide_output(JPG)/outputhide_28.jpg")

# %%
cover1 = np.array(cover1)
cover2 = np.array(cover2)

print(cover1.shape)
print(cover2.shape)
# Out:
# (619, 1101, 3)
# (619, 1101, 3)

# %%
sub = cover1 - cover2
np.sum(sub)
# Out:
# 0
