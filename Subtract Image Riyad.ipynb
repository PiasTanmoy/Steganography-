# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers.core import Activation
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.utils import np_utils
np.random.seed(0)
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
from sklearn.utils import shuffle
import pandas as pd
from PIL import Image
import cv2
# Out:
# Using TensorFlow backend.

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-f99237a1-4fec-44f9-81bf-3ab706fa10f6" name="files[]" multiple disabled />
#      <output id="result-f99237a1-4fec-44f9-81bf-3ab706fa10f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-6fa82f7e-a2e2-4222-8fec-312506041cef" name="files[]" multiple disabled />
#      <output id="result-6fa82f7e-a2e2-4222-8fec-312506041cef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
image = cv2.imread("output_hide_1.bmp")
print(image)
# Out:
# None

# %%
cover1 = cv2.imread("drive/My Drive/Steganography/dataset/bmp input/set-5/cover_5.bmp")
cover2 = cv2.imread("drive/My Drive/Steganography/dataset/output/Invisible_Secret_4_Output/Invisible Secrets 4(BMP)/GOST/output_cover/output_cover-26.bmp")

# %%
# cover1 = cv2.imread("hide_3.bmp")
# cover2 = cv2.imread("hide_out.bmp")

# %%
cover1 = np.array(cover1)
cover2 = np.array(cover2)

print(cover1.shape)
print(cover2.shape)
# Out:
# (850, 1512, 3)
# (850, 1512, 3)

# %%
# s = cover1.shape
# cover2.reshape(s)

# print(cover1.shape, cover2.shape)

# %%
sub = cover1 - cover2
np.sum(sub)
# Out:
# 262383334
