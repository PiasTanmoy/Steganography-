# %% [markdown]
# # Default

# %%
A = [[1,2], [2,3]]
B = [[1,2], [2,3]]

# %%
A = [ [[10,20], [20,30]], [[10,20], [20,30]], [[10,20], [20,30]]]
B = [ [[10,20], [30,20]], [[10,20], [30,20]], [[10,20], [30,20]]]

# %%
A = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/white_600.png")
B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/white_600.png")
print(A.shape)
print(B.shape)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Read

# %%
import cv2
A = cv2.imread("drive/My Drive/Steganography/dataset/bmp input/set-1/cover_1.bmp")
B = cv2.imread("drive/My Drive/Steganography/dataset/output/Hide_in_Picture/Output_cover/output_1.bmp")
B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/bmp input/set-5/cover_5.bmp")
print(A.shape)
print(B.shape)

# %% [markdown]
# # Preproces images

# %%
A = np.array(A)
B = np.array(B)
A = A.astype("float")
B = B.astype("float")
M = A.shape[0]
N = B.shape[1]

# %% [markdown]
# # Main

# %%
all_values = [ ]
all_values.append(MSE(A,B))
all_values.append(PSNR(A,B))
all_values.append(AD(A, B))
all_values.append(MD(A, B))
all_values.append(MAE(A,B))
all_values.append(PMSE(A, B))
all_values.append(SSIM(A, B))
all_values.append(DSSM(A, B))
all_values.append(SNR(A, B))
all_values.append(SC(A, B))
all_values.append(NCC(A, B))
all_values.append(CQ(A, B))
all_values.append(IF(A, B))



print(all_values)

print("MSE: " , MSE(A,B))
print("PSNR: " , PSNR(A,B))
print("AD: ", AD(A, B))
print("MD: ", MD(A, B))
print("MAE: " , MAE(A,B))
print("PMSE: ", PMSE(A, B))
print("SSIM: ", SSIM(A, B))
print("DSSIM: ", DSSM(A, B))
print("SNR: ", SNR(A, B))
print("SC: ", SC(A, B))
print("NCC: ", NCC(A, B))
print("CQ: ", CQ(A, B))
print("IF: ", IF(A, B))

# %% [markdown]
# # Import

# %%
from skimage.measure import compare_mse as sk_mse
from skimage.measure import compare_ssim as sk_ssim
from skimage.measure import compare_mse as sk_mse
import numpy as np
import numpy 
import math
import cv2

# %% [markdown]
# # Mean Square Error(MSE):

# %%
mse = numpy.mean( (A - B) ** 2 )
print(mse)

# %%
sum = 0
for i in range(M):
  for j in range(N):
    sum += (A[i][j] - B[i][j])**2
mse = np.sum((sum / (M*N)))/3
print(mse)

# %%
mse = (np.square(A - B)).mean(axis=None)
print(mse)

# %%
sk_mse(A, B)

# %%
sk_nrmse(A,B)

# %%
def MSE(A, B):
  return sk_mse(A, B)

# %% [markdown]
# # Peak Signal to Noise Ratio(PSNR):

# %%
def PSNR(img1, img2):
    #mse = numpy.mean( (img1 - img2) ** 2 )
    mse = sk_mse(img1, img2)
    if mse == 0:
      return 100
    PIXEL_MAX = 255.0
    return 10 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %% [markdown]
# # Average Difference(AD)

# %%
def AD(A, B):
  return np.abs(numpy.mean(A - B))

# %% [markdown]
# # Maximum Difference(MD):

# %%
def MD(A, B):
  return np.max(A-B)

# %% [markdown]
# # Mean Absolute Error(MAE):

# %%
def MAE(A,B):
  sum = 0
  for i in range(M):
    for j in range(N):
      sum += np.abs(A[i][j] - B[i][j])

  MAE = (1/(M*N))*sum
  MAE = np.average(MAE)
  return MAE

# %% [markdown]
# # Peak Mean Square Error(PMSE)

# %%
def PMSE(A, B):
  mse = sk_mse(A, B)
  pmse = mse / np.max(A)
  return pmse

# %% [markdown]
# # Structural Similarity Index (SSIM)

# %%
def SSIM(A, B):
  return sk_ssim(A,B, multichannel=True)

# %% [markdown]
# # Structural Dissimilarity (DSSIM)

# %%
def DSSIM(A,B):
  ssim_xy = sk_ssim(A,B, multichannel=True)
  dssm = 1.0/ (1-ssim_xy)
  return dssm

# %% [markdown]
# # SNR

# %%
def SNR(img1, img2):
    mse = sk_mse(img1, img2)
    if mse == 0:
      return 100
    R = np.sum(img1)
    return 10 * math.log10(R / math.sqrt(mse))

# %% [markdown]
# # Structure Content

# %%
def SC(A,B):
  x = np.sum(A)**2
  y = np.sum(B)**2
  SC_val = x/y
  return SC_val

# %% [markdown]
# # N. Cross-Correlation

# %%
def NCC(A, B):
  return np.sum(A*B) / np.sum(A**2)

# %% [markdown]
# # Correlation Quality

# %%
def CQ(A, B):
  return np.sum(A*B) / np.sum(A)

# %% [markdown]
# # Image Fidelity

# %%
def IF(A,B):
  return (1 - ( np.sum((A-B)**2) / np.sum(A**2) ))

# %% [markdown]
# # Main

# %%
all_values = [ ]
all_values.append(MSE(A,B))
all_values.append(PSNR(A,B))
all_values.append(AD(A, B))
all_values.append(MD(A, B))



print(all_values)
