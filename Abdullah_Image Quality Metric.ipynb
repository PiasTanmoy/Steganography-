# %% [markdown]
# # Default

# %%
A = [[1,2], [2,3]]
B = [[1,2], [2,3]]

# %%
A = [ [[10,20], [20,30]], [[10,20], [20,30]], [[10,20], [20,30]]]
B = [ [[10,20], [30,20]], [[10,20], [30,20]], [[10,20], [30,20]]]

# %%
A = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/white_600.png")
B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/black_600.png")
print(A.shape)
print(B.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8deaffe84def> in <module>()
#       1
# ----> 2 A = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/white_600.png")
#       3 B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/black_600.png")
#       4 print(A.shape)
#       5 print(B.shape)
#
# NameError: name 'cv2' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/black_600.png")
B.fill(1)
B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1baca4d236d3> in <module>()
# ----> 1 B = cv2.imread("drive/My Drive/Google_Colab/Steganography/dataset/best_worst_image/black_600.png")
#       2 B.fill(1)
#       3 B
#
# NameError: name 'cv2' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Read

# %%
import cv2
A = cv2.imread("drive/My Drive/Steganography/dataset/bmp input/set-1/cover_1.bmp")
B = cv2.imread("drive/My Drive/Steganography/dataset/output/Image Steganography (PNG Image)/output_cover-1.bmp")
print(A.shape)
print(B.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4590eec13914> in <module>()
#       2 A = cv2.imread("drive/My Drive/Steganography/dataset/bmp input/set-1/cover_1.bmp")
#       3 B = cv2.imread("drive/My Drive/Steganography/dataset/output/Image Steganography (PNG Image)/output_cover-1.bmp")
# ----> 4 print(A.shape)
#       5 print(B.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# # Preproces images

# %%
A = np.array(A)
B = np.array(B)
A = A.astype("float")
B = B.astype("float")
M = A.shape[0]
N = B.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4bb6cbffbf59> in <module>()
# ----> 1 A = np.array(A)
#       2 B = np.array(B)
#       3 A = A.astype("float")
#       4 B = B.astype("float")
#       5 M = A.shape[0]
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Main

# %%
all_values = [ ]
all_values.append(MSE(A,B))
all_values.append(PSNR(A,B))
all_values.append(AD(A, B))
all_values.append(MD(A, B))
all_values.append(MAE(A,B))
all_values.append(PMSE(A, B))
all_values.append(SSIM(A, B))
all_values.append(DSSM(A, B))
all_values.append(SNR(A, B))
all_values.append(SC(A, B))
all_values.append(NCC(A, B))
all_values.append(CQ(A, B))
all_values.append(IF(A, B))



print(all_values)

print("MSE: " , MSE(A,B))
print("PSNR: " , PSNR(A,B))
print("AD: ", AD(A, B))
print("MD: ", MD(A, B))
print("MAE: " , MAE(A,B))
print("PMSE: ", PMSE(A, B))
print("SSIM: ", SSIM(A, B))
print("DSSIM: ", DSSM(A, B))
print("SNR: ", SNR(A, B))
print("SC: ", SC(A, B))
print("NCC: ", NCC(A, B))
print("CQ: ", CQ(A, B))
print("IF: ", IF(A, B))

# %% [markdown]
# # RUN

# %%
import cv2
import numpy as np
#A = cv2.imread("/content/drive/My Drive/Steganography/images steganography final/output/Invisible_secret4/Input/cover_5.jpg")
#B = cv2.imread("drive/My Drive/Steganography/images steganography final/output/Invisible_secret4/Invisible_secret4(BMP)/output/output_2.jpg")
#A.fill(1)

A = cv2.imread("drive/My Drive/Steganography/images steganography final/bmp input/set-5/cover_5.bmp")
B = cv2.imread("/content/drive/My Drive/Steganography/images steganography final/output/s_tools/Triple_DES/Cover_output/output_27.bmp")

print(A.shape)
print(B.shape)


A = np.array(A)
B = np.array(B)
A = A.astype("float")
B = B.astype("float")
M = A.shape[0]
N = B.shape[1]


all_values = [ ]
all_values.append(MSE(A,B))
all_values.append(PSNR(A,B))
all_values.append(AD(A, B))
all_values.append(MD(A, B))
all_values.append(MAE(A,B))
all_values.append(PMSE(A, B))
all_values.append(SSIM(A, B))
all_values.append(DSSIM(A, B))
all_values.append(SNR(A, B))
all_values.append(SC(A, B))
all_values.append(NCC(A, B))
all_values.append(CQ(A, B))
all_values.append(IF(A, B))


print(all_values)

print("MSE: " , MSE(A,B))
print("PSNR: " , PSNR(A,B))
print("AD: ", AD(A, B))
print("MD: ", MD(A, B))
print("MAE: " , MAE(A,B))
print("PMSE: ", PMSE(A, B))
print("SSIM: ", SSIM(A, B))
print("DSSIM: ", DSSIM(A, B))
print("SNR: ", SNR(A, B))
print("SC: ", SC(A, B))
print("NCC: ", NCC(A, B))
print("CQ: ", CQ(A, B))
print("IF: ", IF(A, B))
# Out:
# (850, 1512, 3)
# (850, 1512, 3)
# [0.1678389874468306, 55.88187510058827, -0.01037296400041498, 1.0, 0.1678389874468306, 2.581145520135803e-06, 0.9467410792528939, 18.776197226158317, 55.52614902135504, 0.9998147207736141, 0.9999906290992028, 178.37609218024187, 0.9999915956069958]
# MSE:  0.1678389874468306
# PSNR:  55.88187510058827
# AD:  -0.01037296400041498
# MD:  1.0
# MAE:  0.1678389874468306
# PMSE:  2.581145520135803e-06
# SSIM:  0.9467410792528939
# DSSIM:  18.776197226158317
# SNR:  55.52614902135504
# SC:  0.9998147207736141
# NCC:  0.9999906290992028
# CQ:  178.37609218024187
# IF:  0.9999915956069958

# %% [markdown]
# # Import

# %%
from skimage.measure import compare_mse as sk_mse
from skimage.measure import compare_ssim as sk_ssim
from skimage.measure import compare_mse as sk_mse
import numpy as np
import numpy 
import math
import cv2

# %% [markdown]
# # Mean Square Error(MSE):

# %%
def MSE(A, B):
  return sk_mse(A, B)

# %%
mse = numpy.mean( (A - B) ** 2 )
print(mse)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9ae7963c82ce> in <module>()
# ----> 1 mse = numpy.mean( (A - B) ** 2 )
#       2 print(mse)
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
sum = 0
for i in range(M):
  for j in range(N):
    sum += (A[i][j] - B[i][j])**2
mse = np.sum((sum / (M*N)))/3
print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9ff8acd84598> in <module>()
#       1 sum = 0
# ----> 2 for i in range(M):
#       3   for j in range(N):
#       4     sum += (A[i][j] - B[i][j])**2
#       5 mse = np.sum((sum / (M*N)))/3
#
# NameError: name 'M' is not defined

# %%
mse = (np.square(A - B)).mean(axis=None)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9d8693856c54> in <module>()
# ----> 1 mse = (np.square(A - B)).mean(axis=None)
#       2 print(mse)
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
sk_mse(A, B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ac01ad0632ca> in <module>()
# ----> 1 sk_mse(A, B)
#
# /usr/local/lib/python3.6/dist-packages/skimage/measure/simple_metrics.py in compare_mse(im1, im2)
#      39
#      40     """
# ---> 41     _assert_compatible(im1, im2)
#      42     im1, im2 = _as_floats(im1, im2)
#      43     return np.mean(np.square(im1 - im2), dtype=np.float64)
#
# /usr/local/lib/python3.6/dist-packages/skimage/measure/simple_metrics.py in _assert_compatible(im1, im2)
#      12 def _assert_compatible(im1, im2):
#      13     """Raise an error if the shape and dtype do not match."""
# ---> 14     if not im1.shape == im2.shape:
#      15         raise ValueError('Input images must have the same dimensions.')
#      16     return
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
sk_nrmse(A,B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2116255ff161> in <module>()
# ----> 1 sk_nrmse(A,B)
#
# NameError: name 'sk_nrmse' is not defined

# %%
def MSE(A, B):
  return sk_mse(A, B)

# %% [markdown]
# # Peak Signal to Noise Ratio(PSNR):

# %%
def PSNR(img1, img2):
    #mse = numpy.mean( (img1 - img2) ** 2 )
    mse = sk_mse(img1, img2)
    if mse == 0:
      
      return 100
    M = 255.0
    return 10 * math.log10(M**2 / mse)

# %% [markdown]
# # Average Difference(AD)

# %%
def AD(A, B):
  return numpy.mean(A - B)

# %% [markdown]
# # Maximum Difference(MD):

# %%
def MD(A, B):
  return np.max(A-B)

# %% [markdown]
# # Mean Absolute Error(MAE):

# %%
def MAE(A,B):
  sum = 0
  for i in range(M):
    for j in range(N):
      sum += np.abs(A[i][j] - B[i][j])

  MAE = (1/(M*N))*sum
  MAE = np.average(MAE)
  return MAE

# %% [markdown]
# # Peak Mean Square Error(PMSE)

# %%
def PMSE(A, B):
  mse = sk_mse(A, B)
  pmse = mse / np.max(A)**2
  return pmse

# %% [markdown]
# # Structural Similarity Index (SSIM)

# %%
def SSIM(A, B):
  return sk_ssim(A,B, multichannel=True)

# %% [markdown]
# # Structural Dissimilarity (DSSIM)

# %%
def DSSIM(A,B):
  ssim_xy = sk_ssim(A,B, multichannel=True)
  dssm = 1.0/ (1-ssim_xy)
  return dssm

# %% [markdown]
# # SNR

# %%
def SNR(img1, img2):
    mse = sk_mse(img1, img2)
    if mse == 0:
      return 100
    R2 = np.sum(img1**2)
    if R2 == 0.0:
      R2 = 0.00000000001
    #print(mse, R2, R2 / (mse*M*N) )
    return 10 * math.log10( R2 / (mse*M*N) )

# %% [markdown]
# # Structure Content

# %%
def SC(A,B):
  x = np.sum(A)**2
  y = np.sum(B)**2
  SC_val = x/y
  return SC_val

# %% [markdown]
# # N. Cross-Correlation

# %%
def NCC(A, B):
  
  return np.sum(A*B) / np.sum(A**2)

# %% [markdown]
# # Correlation Quality

# %%
def CQ(A, B):
  return np.sum(A*B) / np.sum(A)

# %% [markdown]
# # Image Fidelity

# %%
def IF(A,B):
  return (1 - ( np.sum((A-B)**2) / np.sum(A**2) ))

# %% [markdown]
# # Main

# %%
all_values = [ ]
all_values.append(MSE(A,B))
all_values.append(PSNR(A,B))
all_values.append(AD(A, B))
all_values.append(MD(A, B))



print(all_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-a5e6918d49aa> in <module>()
#       1 all_values = [ ]
# ----> 2 all_values.append(MSE(A,B))
#       3 all_values.append(PSNR(A,B))
#       4 all_values.append(AD(A, B))
#       5 all_values.append(MD(A, B))
#
# <ipython-input-19-cc28c158b0fb> in MSE(A, B)
#       1 def MSE(A, B):
# ----> 2   return sk_mse(A, B)
#
# /usr/local/lib/python3.6/dist-packages/skimage/measure/simple_metrics.py in compare_mse(im1, im2)
#      39
#      40     """
# ---> 41     _assert_compatible(im1, im2)
#      42     im1, im2 = _as_floats(im1, im2)
#      43     return np.mean(np.square(im1 - im2), dtype=np.float64)
#
# /usr/local/lib/python3.6/dist-packages/skimage/measure/simple_metrics.py in _assert_compatible(im1, im2)
#      12 def _assert_compatible(im1, im2):
# ...
