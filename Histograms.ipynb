# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
'Hide in Picture', 'Openstego', 'Image Steganography', 'Invisible secret 4', 'Online Image steganography', 'S-Tools', "Hide 'N' Send"

objects = ('Hide in Picture', 'Openstego', 'Image Steganography', 'Invisible secret 4', 'Online Image steganography', 'S-Tools', "Hide 'N' Send")
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1, 5]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [2,4,6,8,10]
y=[3,9,11,2,6]
y2=[3,9,11,2,6]
plt.bar(x,y,y2,label ='Bars')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Bar Graph1')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import datetime

x = [
    datetime.datetime(2011, 1, 4, 0, 0),
    datetime.datetime(2011, 1, 5, 0, 0),
    datetime.datetime(2011, 1, 6, 0, 0)
]
x = date2num(x)

#x = [2,4,6]
y = [4, 9, 2]
z = [1, 2, 3]
k = [11, 12, 13]

ax = plt.subplot(111)
ax.bar(x-0.2, y, width=0.2, color='b', align='center')
ax.bar(x, z, width=0.2, color='g', align='center')
ax.bar(x+0.2, k, width=0.2, color='r', align='center')
ax.xaxis_date()

plt.show()

# %%
import numpy as np

N = 7


MSE = (0.19,
0.02,
0.66,
0.51,
8.45,
0.02,
1.07,
)
AD = (0.15,
0,
0.16,
0.12,
0.98,
0,
0.01,
)
MD = (1.00,
1.00,
3.00,
1.00,
9.25,
1.00,
19.37,
)
MAE = (0.19,
0.02,
0.06,
0.51,
8.45,
0.02,
1.07,
)

ind = np.arange(N) 
width = 0.2    
plt.bar(ind, MSE, width, label='MSE')
plt.bar(ind + width, AD, width,label='AD')
plt.bar(ind + width+width, MD, width,label='MD')
plt.bar(ind + width+width+width, MAE, width,label='MAE')

plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
plt.xticks(ind + width / 2, ('1', '2', '3', '4', '5', '6', '7'))
plt.legend(loc='best')



from google.colab import files
plt.savefig("1.png", dpi=200)

#files.download("1.png")
plt.show()

# %%
import numpy as np

N = 7


PSNR = (57.07,
66.52,
51.76,
51.08,
38.86,
66.55,
48.67
)


SSIM = (0.95,
0.98,
0.95,
0.91,
0.84,
0.98,
0.98,

)
DSSIM = (26.04,
173.85,
41.43,
10.73,
6.06,
179.92,
54.20,

)
SNR = (56.71,
66.16,
51.40,
50.73,
38.51,
66.19,
48.31,
)

ind = np.arange(N) 
width = 0.2       
plt.bar(ind, PSNR, width, label='PSNR')
plt.bar(ind + width, SSIM, width,label='SSIM')
plt.bar(ind + width+width, DSSIM, width,label='DSSIM')
plt.bar(ind + width+width+width, SNR, width,label='SNR')

plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
plt.xticks(ind + width / 2, ('1', '2', '3', '4', '5', '6', '7'))
plt.legend(loc='best')



from google.colab import files
plt.savefig("2.png", dpi=200)
#files.download("2.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [[5., 25., 50., 20.],
  [4., 23., 51., 17.],
  [6., 22., 52., 19.]]

X = np.arange(4)
plt.bar(X + 0.00, data[0], color = 'b', width = 0.25)
plt.bar(X + 0.25, data[1], color = 'g', width = 0.25)
plt.bar(X + 0.50, data[2], color = 'r', width = 0.25)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


MSE = (0.19,
0.02,
0.06,
0.51,
0.02,
1.07
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, MSE, width, label='MSE', color='g')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("MSE.png", dpi=200)
files.download("MSE.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


PSNR = (57.07,
66.52,
63.37,
51.08,
66.55,
48.67

)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, PSNR, width, label='PSNR', color='violet')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("PSNR.png", dpi=200)
files.download("PSNR.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


MD = (1.00,
1.00,
3.00,
1.00,
1.00,
19.37
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, MD, width, label='MD', color='violet')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("MD.png", dpi=200)
files.download("MD.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


MAE = (0.19,
0.026,
0.03,
0.51,
0.02,
0.46
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, MAE, width, label='MAE', color='darkblue')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("MAE.png", dpi=200)
files.download("MAE.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


SSIM = (0.95,
0.98,
0.99,
0.91,
0.98,
0.98
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, SSIM, width, label='SSIM', color='gold')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("SSIM.png", dpi=200)
files.download("SSIM.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


DSSIM = (26.04,
173.85,
1484.59,
10.73,
179.92,
54.20
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, DSSIM, width, label='DSSIM', color='brown')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("DSSIM.png", dpi=200)
files.download("DSSIM.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


SNR = (56.71,
66.16,
63.01,
50.73,
66.19,
48.31
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, SNR, width, label='SNR', color='olive')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("SNR.png", dpi=200)
files.download("SNR.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 6


PMSE = (292.00,
41.80,
93.00,
782.00,
41.70,
1660.00
)


ind = np.arange(N) 

width = 0.5       


plt.bar(ind, PMSE, width, label='PMSE', color='darkmagenta')


plt.ylabel('Values')
plt.xlabel('Tools No.')
#plt.title('Metrics')
plt.grid(True)
#plt.xticks(ind , ('1', '2','3', '4','5', '6', '7'))
plt.xticks(ind , ('1', '2','3', '4', '5', '6'))
plt.legend(loc='best')



from google.colab import files


plt.savefig("PMSE.png", dpi=200)
files.download("PMSE.png")
plt.show()
